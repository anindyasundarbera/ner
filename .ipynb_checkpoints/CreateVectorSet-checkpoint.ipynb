# %% [markdown]
# Load the Trained spaCy Model

# %%
import spacy

# Load the trained model
nlp = spacy.load("event_date_time_model_with_alignment")

# %% [markdown]
# Extract Vectors

# %%
import pandas as pd

# Load dataset
data = pd.read_csv('event_data.csv')
# Extract vectors for the sentences
sentences = [f"{row['Verb']} an event on {row['Date']} at {row['Time']} in {row['Country']}" for _, row in data.iterrows()]
# Process sentences to get vectors
vectors = [nlp(sentence).vector for sentence in sentences]
# Check the shape of one vector
print(vectors[0].shape)
print(data)
# print(sentences)
print(vectors)
# Out:
# (0,)
#          Verb                    Date             Time          Country
# 0         add  the day after tomorrow            10:00            Nepal
# 1         fix           next Thursday            18:45            Samoa
# 2    organize              2024-06-15         10:30 PM          Jamaica
# 3         add             this Friday            08:45          Ukraine
# 4        book            this evening     late evening         Paraguay
# ..        ...                     ...              ...              ...
# 995    set up              2nd August         11:00 PM  Kyrgyz Republic
# 996      plan              2024-07-11            04:00          Bahrain
# 997       add  the day after tomorrow            10:00         Portugal
# 998       add          coming weekend            21:00         Slovenia
# 999    create              next month  weekend evening          Armenia
#
# [1000 rows x 4 columns]
# ['add an event on the day after tomorrow at 10:00 in Nepal', 'fix an event on next Thursday at 18:45 in Samoa', 'organize an event on 2024-06-15 at 10:30 PM in Jamaica', 'add an event on this Friday at 08:45 in Ukraine', 'book an event on this evening at late evening in Paraguay', 'arrange an event on the day after tomorrow at 09:00 in Israel', 'create an event on 2024-06-15 at noon in Saint Pierre &amp; Miquelon', 'plan an event on 2024-06-16 at 02:00 AM in Belize', 'set up an event on tomorrow at 12:00 in Japan', 'reserve an event on 2024-06-16 at 10:00 in Guernsey', 'create an event on 2024-06-21 at 06:00 in Hungary', 'set up an event on next morning at 23:59 in Latvia', 'fix an event on next morning at late evening in Angola', 'schedule an event on 2024-06-23 at weekend evening in Algeria', 'add an event on tomorrow at 10:00 in Ecuador', 'create an event on 2024-06-23 at 11:00 PM in Tanzania', 'schedule an event on 2024-06-29 at 23:59 in Bermuda', 'organize an event on this Saturday at 10:00 in Sierra Leone', 'hold an event on 2024-06-21 at evening in Anguilla', 'schedule an event on next Monday at 11:00 PM in Croatia', 'book an event on 2024-06-21 at 02:00 AM in Iran', 'create an event on next year at noon in Kyrgyz Republic', 'reserve an event on 2nd August at 14:00 in Afghanistan', 'arrange an event on 2024-07-07 at early morning in Barbados', 'add an event on this Wednesday at midnight in Ghana', 'set up an event on 2024-06-30 at late evening in Swaziland', 'book an event on 2024-06-16 at 21:00 in Liberia', 'hold an event on 2024-07-04 at afternoon in Kuwait', 'plan an event on 2024-06-15 at 14:00 in Luxembourg', 'book an event on this evening at 02:00 AM in Mali', 'organize an event on next year at 23:59 in Aruba', 'plan an event on this afternoon at 10:30 PM in Greece', 'plan an event on 2024-06-25 at 02:00 AM in Gabon', 'fix an event on 2024-06-24 at 09:00 in Luxembourg', 'plan an event on this evening at weekend evening in Austria', 'reserve an event on 2024-06-16 at 16:20 in Cayman Islands', 'schedule an event on 2024-06-14 at 18:45 in St Vincent', 'book an event on 2024-07-06 at weekend evening in Guinea', 'add an event on 2024-07-11 at 16:20 in Uganda', 'schedule an event on 2024-06-14 at 09:00 AM in Cote D Ivoire', 'arrange an event on 2024-06-30 at morning in Moldova', 'create an event on 2024-06-25 at late evening in Gambia', 'plan an event on 2024-06-22 at 10:30 PM in Albania', 'arrange an event on 2nd August at 07:30 in Cambodia', 'create an event on coming weekend at 14:00 in Belize', 'plan an event on next Monday at 23:59 in Uganda', 'plan an event on first Monday of July at evening in Guatemala', 'hold an event on next Thursday at 16:20 in Equatorial Guinea', 'organize an event on 2024-06-15 at 07:30 in South Korea', 'create an event on next Thursday at evening in Antigua &amp; Barbuda', 'fix an event on 2024-06-15 at early morning in Honduras', 'plan an event on 2nd August at 21:00 in Egypt', 'organize an event on coming Friday at 14:00 in Djibouti', 'set up an event on 2024-06-30 at noon in Mali', 'arrange an event on 2024-07-06 at 10:00 in Benin', 'create an event on 2024-06-15 at 07:30 in Equatorial Guinea', 'plan an event on this afternoon at 07:30 in St. Lucia', 'add an event on 2024-06-29 at 21:00 in Togo', 'arrange an event on next Thursday at 10:30 PM in Yemen', 'reserve an event on weekend evening at 10:30 PM in Thailand', 'set up an event on weekend evening at afternoon in Colombia', 'set up an event on 2024-07-06 at 18:45 in Kazakhstan', 'add an event on coming weekend at weekend evening in Andorra', 'add an event on first Monday of July at 11:00 PM in Sierra Leone', 'arrange an event on 2024-06-15 at morning in Australia', 'plan an event on 2024-06-15 at 18:45 in Tajikistan', 'fix an event on next Monday at 10:30 PM in Zambia', 'set up an event on 2024-06-22 at 07:30 in Gibraltar', 'fix an event on first Monday of July at 16:20 in Madagascar', 'create an event on 2024-07-04 at midnight in Mo ...

# %% [markdown]
# Dimensionality Reduction

# %%
from sklearn.decomposition import PCA
import numpy as np
# Perform PCA to reduce the dimensions to 2D
pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(vectors)
# Check the shape of the reduced vectors
print(reduced_vectors.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Perform PCA to reduce the dimensions to 2D
#       4 pca = PCA(n_components=2)
# ----> 5 reduced_vectors = pca.fit_transform(vectors)
#       6 # Check the shape of the reduced vectors
#       7 print(reduced_vectors.shape)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\decomposition\_pca.py:462, in PCA.fit_transform(self, X, y)
#     439 """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441 Parameters
#    (...)
#     458 C-ordered array, use 'np.ascontiguousarray'.
#     459 """
#     460 self._validate_params()
# --> 462 U, S, Vt = self._fit(X)
#     463 U = U[:, : self.n_components_]
#     465 if self.whiten:
#     466     # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\decomposition\_pca.py:485, in PCA._fit(self, X)
#     479 if issparse(X):
#     480     raise TypeError(
#     481         "PCA does not support sparse input. See "
#     482         "TruncatedSVD for a possible alternative."
#     483     )
# --> 485 X = self._validate_data(
#     486     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     487 )
#     489 # Handle n_components==None
#     490 if self.n_components is None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:940, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     938     n_features = array.shape[1]
#     939     if n_features < ensure_min_features:
# --> 940         raise ValueError(
#     941             "Found array with %d feature(s) (shape=%s) while"
#     942             " a minimum of %d is required%s."
#     943             % (n_features, array.shape, ensure_min_features, context)
#     944         )
#     946 if copy:
#     947     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     948         # only make a copy if `array` and `array_orig` may share memory`
#
# ValueError: Found array with 0 feature(s) (shape=(1000, 0)) while a minimum of 1 is required by PCA.

# %% [markdown]
# Plot Vectors with Matplotlib

# %%
import matplotlib.pyplot as plt

# Plot the reduced vectors
plt.figure(figsize=(10, 8))
plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], alpha=0.7, c='blue')
plt.title('2D Visualization of Sentence Vectors')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.grid(True)
plt.show()
